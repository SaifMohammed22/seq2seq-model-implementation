# %%
# !git clone https://github.com/SaifMohammed22/seq2seq-model-implementation.git
# %cd /content/seq2seq-model-implementation
# Out:
# Cloning into 'seq2seq-model-implementation'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 86 (delta 33), reused 66 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 3.31 MiB | 7.27 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# /content/seq2seq-model-implementation

# %%
# !pwd
# Out:
# /content/seq2seq-model-implementation

# %%
# !python main.py
# Out:
# Using device: cuda
# Preparing data...
# Reading lines....
# Traceback (most recent call last):
#   File "/content/seq2seq-model-implementation/main.py", line 62, in <module>
#     main()
#   File "/content/seq2seq-model-implementation/main.py", line 19, in main
#     input_lang, output_lang, pairs = prepareData('eng', 'fra', True)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/seq2seq-model-implementation/prep_data.py", line 7, in prepareData
#     input_lang, output_lang, pairs = readLang(lang1, lang2, reverse=reverse)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/seq2seq-model-implementation/data_preprocessing.py", line 24, in readLang
#     lines = open(f"data/{lang1}-{lang2}.txt").read().strip().split("\n")
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'data/eng-fra.txt'
